# %%
import tensorflow as tf
from keras import layers, Model
from keras.applications import VGG16
from keras.optimizers import Adam
from keras.preprocessing import image_dataset_from_directory
import numpy as np
import pandas as pd

#connect to google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Load image data
ds_train = image_dataset_from_directory('/content/gdrive/MyDrive/ECG/Train', batch_size=32, image_size=(224, 224))
ds_test = image_dataset_from_directory('/content/gdrive/MyDrive/ECG/Test', batch_size=32, image_size=(224, 224))

# Load numeric array data
X = np.load('/content/gdrive/MyDrive/ECG/items_AF&SR.npy')
y = np.load('/content/gdrive/MyDrive/ECG/arr2D_AF&SR_label.npy')

# Load metadata
metadata = pd.read_csv('/content/gdrive/MyDrive/ECG/Matadata_ECG.csv')
# Out:
# Found 2869 files belonging to 2 classes.
# Found 718 files belonging to 2 classes.

# %%
metadata.head(5)
# Out:
#                           Location  Labels
# 0   /ECG Dataset/ECG/Test/AF/0.png       1
# 1  /ECG Dataset/ECG/Train/SR/1.png       0
# 2  /ECG Dataset/ECG/Train/SR/2.png       0
# 3  /ECG Dataset/ECG/Train/AF/3.png       1
# 4  /ECG Dataset/ECG/Train/SR/4.png       0

# %%
# Create a new column 'Location_final' by adjusting 'Location'
metadata['Location_final'] = metadata['Location'].apply(lambda x: x.replace('/ECG Dataset/ECG/', '/content/gdrive/MyDrive/ECG/'))

# Drop the original 'Location' column if needed
metadata.drop(columns=['Location'], inplace=True)

# Rename the new column to 'Location' if needed
metadata.rename(columns={'Location_final': 'Location'}, inplace=True)

# %%
metadata.head(5)
# Out:
#    Labels                                    Location
# 0       1   /content/gdrive/MyDrive/ECG/Test/AF/0.png
# 1       0  /content/gdrive/MyDrive/ECG/Train/SR/1.png
# 2       0  /content/gdrive/MyDrive/ECG/Train/SR/2.png
# 3       1  /content/gdrive/MyDrive/ECG/Train/AF/3.png
# 4       0  /content/gdrive/MyDrive/ECG/Train/SR/4.png

# %%
# Preprocessing
import numpy as np
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X.reshape(-1, X.shape[-1])).reshape(X.shape)

print(X_scaled)
# Out:
# [[[ 0.80705828 -0.4588596  -0.25228113]
#   [ 0.80705828 -0.4588596  -0.25228113]
#   [ 0.80705828 -0.4588596  -0.25228113]
#   ...
#   [-0.71186622 -0.24757386 -0.22215566]
#   [-0.71770824 -0.23683052 -0.22215566]
#   [-0.7060242  -0.22608717 -0.22215566]]
#
#  [[-0.7410763  -0.17237046 -0.10165378]
#   [-0.7410763  -0.17237046 -0.10165378]
#   [-0.7410763  -0.17237046 -0.10165378]
#   ...
#   [ 0.035912    0.08546976 -0.07152831]
#   [ 0.04759603  0.07830753 -0.06550321]
#   [ 0.04759603  0.07472642 -0.05646557]]
#
#  [[-2.72736219 -1.55109943 -2.18031125]
#   [-2.72736219 -1.55109943 -2.18031125]
#   [-2.72736219 -1.55109943 -2.18031125]
#   ...
#   [-0.35550316  0.38628336  1.4076323 ]
#   [-0.41976535  0.38270224  1.39558212]
#   [-0.45481746  0.38270224  1.36846919]]
#
#  ...
#
#  [[ 0.16443638 -0.24399274  0.16947546]
#   [ 0.16443638 -0.24399274  0.16947546]
#   [ 0.16443638 -0.24399274  0.16947546]
#   ...
#   [-0.05171826 -0.13655932 -0.06550321]
#   [-0.08677037 -0.03270701 -0.05947812]
#   [-0.0984544   0.03533416 -0.07454085]]
#
#  [[ 0.89468854  0.52594681  0.04897358]
#   [ 0.89468854  0.52594681  0.04897358]
#   [ 0.89468854  0.52594681  0.04897358]
#   ...
#   [ 0.72527004  0.16783539  0.1785131 ]
#   [ 0.87132047  0.16425428  0.19056329]
#   [ 0.98816082  0.17499762  0.20261348]]
#
#  [[ 0.10601621  0.32898553 -0.0263401 ]
#   [ 0.10601621  0.32898553 -0.0263401 ]
#   [ 0.10601621  0.32898553 -0.0263401 ]
#   ...
#   [-0.57749982  0.39344559 -0.40290848]
#   [-0.55997377  0.43283784 -0.39989594]
#   [-0.56581579  0.43641896 -0.3848332 ]]]

# %%
import tensorflow as tf
from keras import layers, Model
from keras.applications import VGG16
from keras.optimizers import Adam
from keras.preprocessing.image import img_to_array, load_img
import numpy as np
import pandas as pd



def load_images(file_paths):
    images = []
    for path in file_paths:
        img = load_img(path, target_size=(224, 224))
        img_array = img_to_array(img)
        images.append(img_array)
    return np.array(images)


# Load image data using the adjusted metadata DataFrame
X_train_images = load_images(metadata[metadata['Labels'] == 0]['Location'])
X_test_images = load_images(metadata[metadata['Labels'] == 1]['Location'])

# Define VGG16 base model
vgg_base = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze VGG16 layers
for layer in vgg_base.layers:
    layer.trainable = False

# Add GlobalAveragePooling2D layer to reduce spatial dimensions
vgg_output = layers.GlobalAveragePooling2D()(vgg_base.output)

# Define CNN-bidirectional-LSTM model for numeric array data
model_numeric = tf.keras.Sequential([
    layers.Conv1D(64, 3, activation='relu', input_shape=(1000, 3)),
    layers.MaxPooling1D(2),
    layers.Conv1D(128, 3, activation='relu'),
    layers.MaxPooling1D(2),
    layers.Conv1D(256, 3, activation='relu'),
    layers.MaxPooling1D(2),
    layers.Bidirectional(layers.LSTM(64, return_sequences=True)),
    layers.GlobalAveragePooling1D(),
    layers.Dense(64, activation='relu')
])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 2s 0us/step

# %%
# Ensure consistent number of samples
num_samples = min(len(metadata), len(X_scaled), len(y))
metadata = metadata.iloc[:num_samples]
X_scaled = X_scaled[:num_samples]
y = y[:num_samples]

# Split data into train and test sets
test_indices = np.arange(4, num_samples, 5)  # Every 5th index starting from the 5th
train_indices = np.setdiff1d(np.arange(num_samples), test_indices)

X_train_images = load_images(metadata.iloc[train_indices]['Location'])
X_train_numeric = X_scaled[train_indices]
y_train = y[train_indices]

X_test_images = load_images(metadata.iloc[test_indices]['Location'])
X_test_numeric = X_scaled[test_indices]
y_test = y[test_indices]

# %%
print(len(X_train_images))
print(len(X_train_numeric))
print(len(X_test_images))
print(len(X_test_numeric))
print(len(y_train))
print(len(y_test))
# Out:
# 2870
# 2870
# 717
# 717
# 2870
# 717

# %%
# Define fusion layer to combine outputs of VGG16 and CNN-bidirectional-LSTM
fusion_layer = layers.Concatenate()([vgg_output, model_numeric.output])

# Add attention layer
attention_probs = layers.Dense(1, activation='tanh')(fusion_layer)
attention_probs = layers.Flatten()(attention_probs)
attention_probs = layers.Activation('softmax')(attention_probs)
attention_probs = layers.RepeatVector(64)(attention_probs)
attention_probs = layers.Permute([2, 1])(attention_probs)

attention_probs = layers.Reshape((-1, 64))(attention_probs)

# Reshape fusion_layer to match the shape of attention_probs
fusion_layer_reshaped = layers.Reshape((-1, 1, 64))(fusion_layer)

# Perform element-wise multiplication
sent_representation = layers.Multiply()([fusion_layer_reshaped, attention_probs])

# Reshape the result to the desired shape
sent_representation = layers.Reshape((-1, 64))(sent_representation)

# Sum along the appropriate axis
sent_representation = layers.Lambda(lambda xin: tf.keras.backend.sum(xin, axis=-2), output_shape=(64,))(sent_representation)
# Add classification layer
output_layer = layers.Dense(1, activation='sigmoid')(sent_representation)

# Create multimodal model
multimodal_model = Model(inputs=[vgg_base.input, model_numeric.input], outputs=output_layer)

# Compile the model
multimodal_model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# Train the model using pre-split datasets
multimodal_model.fit([X_train_images, X_train_numeric], y_train, epochs=80)

# Evaluate the model using pre-split test datasets
loss, accuracy = multimodal_model.evaluate([X_test_images, X_test_numeric], y_test)
print("Test Accuracy:", accuracy)
# Out:
# Epoch 1/80
# 90/90 [==============================] - 18s 142ms/step - loss: 3.7426 - accuracy: 0.6641
# Epoch 2/80
# 90/90 [==============================] - 13s 143ms/step - loss: 0.5183 - accuracy: 0.8624
# Epoch 3/80
# 90/90 [==============================] - 13s 146ms/step - loss: 0.3621 - accuracy: 0.9091
# Epoch 4/80
# 90/90 [==============================] - 13s 146ms/step - loss: 0.2204 - accuracy: 0.9383
# Epoch 5/80
# 90/90 [==============================] - 13s 143ms/step - loss: 0.2147 - accuracy: 0.9415
# Epoch 6/80
# 90/90 [==============================] - 13s 144ms/step - loss: 0.1370 - accuracy: 0.9631
# Epoch 7/80
# 90/90 [==============================] - 13s 142ms/step - loss: 0.1389 - accuracy: 0.9561
# Epoch 8/80
# 90/90 [==============================] - 13s 145ms/step - loss: 0.1170 - accuracy: 0.9641
# Epoch 9/80
# 90/90 [==============================] - 13s 146ms/step - loss: 0.0973 - accuracy: 0.9683
# Epoch 10/80
# 90/90 [==============================] - 13s 145ms/step - loss: 0.0764 - accuracy: 0.9732
# Epoch 11/80
# 90/90 [==============================] - 13s 143ms/step - loss: 0.0535 - accuracy: 0.9850
# Epoch 12/80
# 90/90 [==============================] - 13s 143ms/step - loss: 0.0683 - accuracy: 0.9784
# Epoch 13/80
# 90/90 [==============================] - 13s 145ms/step - loss: 0.1131 - accuracy: 0.9645
# Epoch 14/80
# 90/90 [==============================] - 13s 143ms/step - loss: 0.0402 - accuracy: 0.9864
# Epoch 15/80
# 90/90 [==============================] - 13s 144ms/step - loss: 0.0329 - accuracy: 0.9875
# Epoch 16/80
# 90/90 [==============================] - 13s 145ms/step - loss: 0.0285 - accuracy: 0.9882
# Epoch 17/80
# 90/90 [==============================] - 13s 144ms/step - loss: 0.0155 - accuracy: 0.9930
# Epoch 18/80
# 90/90 [==============================] - 13s 143ms/step - loss: 0.0091 - accuracy: 0.9962
# Epoch 19/80
# 90/90 [==============================] - 13s 143ms/step - loss: 0.1062 - accuracy: 0.9742
# Epoch 20/80
# 90/90 [==============================] - 13s 143ms/step - loss: 0.0851 - accuracy: 0.9767
# Epoch 21/80
# 90/90 [==============================] - 13s 143ms/step - loss: 0.0435 - accuracy: 0.9861
# Epoch 22/80
# 90/90 [==============================] - 13s 143ms/step - loss: 0.0529 - accuracy: 0.9798
# Epoch 23/80
# 90/90 [==============================] - 13s 143ms/step - loss: 0.0662 - accuracy: 0.9791
# Epoch 24/80
# 90/90 [==============================] - 13s 144ms/step - loss: 0.0354 - accuracy: 0.9889
# Epoch 25/80
# 90/90 [==============================] - 13s 143ms/step - loss: 0.0452 - accuracy: 0.9875
# Epoch 26/80
# 90/90 [==============================] - 13s 143ms/step - loss: 0.0345 - accuracy: 0.9861
# Epoch 27/80
# 90/90 [==============================] - 13s 143ms/step - loss: 0.0232 - accuracy: 0.9927
# Epoch 28/80
# 90/90 [==============================] - 13s 143ms/step - loss: 0.0222 - accuracy: 0.9920
# Epoch 29/80
# 90/90 [==============================] - 13s 143ms/step - loss: 0.0486 - accuracy: 0.9826
# Epoch 30/80
# 90/90 [==============================] - 13s 143ms/step - loss: 0.0515 - accuracy: 0.9829
# Epoch 31/80
# 90/90 [==============================] - 13s 143ms/step - loss: 0.0264 - accuracy: 0.9899
# Epoch 32/80
# 90/90 [==============================] - 13s 143ms/step - loss: 0.0134 - accuracy: 0.9958
# Epoch 33/80
# 90/90 [==============================] - 13s 143ms/step - loss: 0.0263 - accuracy: 0.9916
# Epoch 34/80
# 90/90 [==============================] - 13s 143ms/step - loss: 0.0105 - accuracy: 0.9958
# Epoch 35/80
# 90/90 [==============================] - 13s 144ms/step - loss: 0.0082 - accuracy: 0.9972
# Epoch 36/80
# 90/90 [==============================] - 13s 143ms/step - loss: 0.0028 - accuracy: 0.9993
# Epoch 37/80
# 90/90 [==============================] - 13s 144ms/step - loss: 0.0082 - accuracy: 0.9979
# Epoch 38/80
# 90/90 [==============================] - 13s 144ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 39/80
# 90/90 [==============================] - 13s 144ms/step - loss: 5.8566e-04 - accuracy: 1.0000
# Epoch 40/80
# 90/90 [==============================] - 13s 143ms/step - loss: 4.3491e-04 - accuracy: 1.0000
# Epoch 41/80
# 90/90 [==============================] - 13s 143ms/step - loss: 3.6235e-04 - accuracy: 1.0000
# Epoch 42/80
# 90/90 [==============================] - 13s 143ms/step - loss: 3.1550e-04 - accuracy: 1.0000
# Epoch 43/80
# 90/90 [==============================] - 13s 143ms/step - loss: 2.7553e-04 - accuracy: 1.0000
# Epoch 44/80
# 90/90 [==============================] - 13s 143ms/step - loss: 2.4506e-04 - accuracy: 1.0000
# Epoch 45/80
# 90/90 [==============================] - 13s 144ms/step - loss: 2.1889e-04 - accuracy: 1.0000
# Epoch 46/80
# 90/90 [==============================] - 13s 143ms/step - loss: 2.0189e-04 - accuracy: 1.0000
# Epoch 47/80
# 90/90 [==============================] - 13s 144ms/step - loss: 1.8015e-04 - accuracy: 1.0000
# Epoch 48/80
# 90/90 [==============================] - 13s 144ms/step - loss: 1.6525e-04 - accuracy: 1.0000
# Epoch 49/80
# 90/90 [==============================] - 13s 144ms/step - loss: 1.5223e-04 - accuracy: 1.0000
# Epoch 50/80
# 90/90 [==============================] - 13s 143ms/step - loss: 1.4016e-04 - accuracy: 1.0000
# Epoch 51/80
# 90/90 [==============================] - 13s 143ms/step - loss: 1.2859e-04 - accuracy: 1.0000
# Epoch 52/80
# 90/90 [==============================] - 13s 143ms/step - loss: 1.2124e-04 - accuracy: 1.0000
# Epoch 53/80
# 90/90 [==============================] - 13s 143ms/step - loss: 1.1123e-04 - accuracy: 1.0000
# Epoch 54/80
# 90/90 [==============================] - 13s 143ms/step - loss: 1.0374e-04 - accuracy: 1.0000
# Epoch 55/80
# 90/90 [==============================] - 13s 144ms/step - loss: 9.6786e-05 - accuracy: 1.0000
# Epoch 56/80
# 90/90 [==============================] - 13s 143ms/step - loss: 8.9859e-05 - accuracy: 1.0000
# Epoch 57/80
# 90/90 [==============================] - 13s 143ms/step - loss: 8.4384e-05 - accuracy: 1.0000
# Epoch 58/80
# 90/90 [==============================] - 13s 144ms/step - loss: 7.9450e-05 - accuracy: 1.0000
# Epoch 59/80
# 90/90 [==============================] - 13s 143ms/step - loss: 7.5145e-05 - accuracy: 1.0000
# Epoch 60/80
# 90/90 [==============================] - 13s 143ms/step - loss: 6.9282e-05 - accuracy: 1.0000
# Epoch 61/80
# 90/90 [==============================] - 13s 143ms/step - loss: 6.5377e-05 - accuracy: 1.0000
# Epoch 62/80
# 90/90 [==============================] - 13s 143ms/step - loss: 6.1942e-05 - accuracy: 1.0000
# Epoch 63/80
# 90/90 [==============================] - 13s 144ms/step - loss: 5.7519e-05 - accuracy: 1.0000
# Epoch 64/80
# 90/90 [==============================] - 13s 144ms/step - loss: 5.4532e-05 - accuracy: 1.0000
# Epoch 65/80
# 90/90 [==============================] - 13s 144ms/step - loss: 5.1614e-05 - accuracy: 1.0000
# Epoch 66/80
# 90/90 [==============================] - 13s 143ms/step - loss: 4.8293e-05 - accuracy: 1.0000
# Epoch 67/80
# 90/90 [==============================] - 13s 143ms/step - loss: 4.5903e-05 - accuracy: 1.0000
# Epoch 68/80
# 90/90 [==============================] - 13s 143ms/step - loss: 4.3198e-05 - accuracy: 1.0000
# Epoch 69/80
# 90/90 [==============================] - 13s 143ms/step - loss: 4.0584e-05 - accuracy: 1.0000
# Epoch 70/80
# 90/90 [==============================] - 13s 144ms/step - loss: 3.8095e-05 - accuracy: 1.0000
# Epoch 71/80
# 90/90 [==============================] - 13s 143ms/step - loss: 3.6208e-05 - accuracy: 1.0000
# Epoch 72/80
# 90/90 [==============================] - 13s 143ms/step - loss: 3.4354e-05 - accuracy: 1.0000
# Epoch 73/80
# 90/90 [==============================] - 13s 143ms/step - loss: 3.2484e-05 - accuracy: 1.0000
# Epoch 74/80
# 90/90 [==============================] - 13s 143ms/step - loss: 3.0786e-05 - accuracy: 1.0000
# Epoch 75/80
# 90/90 [==============================] - 13s 143ms/step - loss: 2.9257e-05 - accuracy: 1.0000
# Epoch 76/80
# 90/90 [==============================] - 13s 143ms/step - loss: 2.7769e-05 - accuracy: 1.0000
# Epoch 77/80
# 90/90 [==============================] - 13s 143ms/step - loss: 2.6264e-05 - accuracy: 1.0000
# Epoch 78/80
# 90/90 [==============================] - 13s 144ms/step - loss: 2.5133e-05 - accuracy: 1.0000
# Epoch 79/80
# 90/90 [==============================] - 13s 144ms/step - loss: 2.3685e-05 - accuracy: 1.0000
# Epoch 80/80
# 90/90 [==============================] - 13s 145ms/step - loss: 2.2621e-05 - accuracy: 1.0000
# 23/23 [==============================] - 4s 128ms/step - loss: 0.5472 - accuracy: 0.9233
# Test Accuracy: 0.9232915043830872

# %%
# Define fusion layer to combine outputs of VGG16 and CNN-bidirectional-LSTM
fusion_layer = layers.Concatenate()([vgg_output, model_numeric.output])

# Add attention layer
attention_probs = layers.Dense(1, activation='tanh')(fusion_layer)
attention_probs = layers.Flatten()(attention_probs)
attention_probs = layers.Activation('softmax')(attention_probs)
attention_probs = layers.RepeatVector(64)(attention_probs)
attention_probs = layers.Permute([2, 1])(attention_probs)

attention_probs = layers.Reshape((-1, 64))(attention_probs)

# Reshape fusion_layer to match the shape of attention_probs
fusion_layer_reshaped = layers.Reshape((-1, 1, 64))(fusion_layer)

# Perform element-wise multiplication
sent_representation = layers.Multiply()([fusion_layer_reshaped, attention_probs])

# Reshape the result to the desired shape
sent_representation = layers.Reshape((-1, 64))(sent_representation)

# Sum along the appropriate axis
sent_representation = layers.Lambda(lambda xin: tf.keras.backend.sum(xin, axis=-2), output_shape=(64,))(sent_representation)
# Add classification layer
output_layer = layers.Dense(1, activation='sigmoid')(sent_representation)

# Create multimodal model
multimodal_model = Model(inputs=[vgg_base.input, model_numeric.input], outputs=output_layer)

# Compile the model
multimodal_model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# Train the model using pre-split datasets and store the history
history = multimodal_model.fit([X_train_images, X_train_numeric], y_train, epochs=100, validation_data=([X_test_images, X_test_numeric], y_test))

# Evaluate the model using pre-split test datasets
loss, test_accuracy = multimodal_model.evaluate([X_test_images, X_test_numeric], y_test)
print("Test Accuracy:", test_accuracy)

# Retrieve the train accuracy from the history
train_accuracy = history.history['accuracy'][-1]
print("Train Accuracy:", train_accuracy)
# Out:
# Epoch 1/100
# 90/90 [==============================] - 45s 335ms/step - loss: 1.8428 - accuracy: 0.6425 - val_loss: 1.5991 - val_accuracy: 0.6890
# Epoch 2/100
# 90/90 [==============================] - 18s 205ms/step - loss: 1.2937 - accuracy: 0.6916 - val_loss: 0.9873 - val_accuracy: 0.7350
# Epoch 3/100
# 90/90 [==============================] - 18s 203ms/step - loss: 0.9583 - accuracy: 0.7286 - val_loss: 0.8086 - val_accuracy: 0.7685
# Epoch 4/100
# 90/90 [==============================] - 16s 176ms/step - loss: 0.7879 - accuracy: 0.7505 - val_loss: 0.6890 - val_accuracy: 0.7727
# Epoch 5/100
# 90/90 [==============================] - 18s 201ms/step - loss: 0.5952 - accuracy: 0.8045 - val_loss: 0.4717 - val_accuracy: 0.8466
# Epoch 6/100
# 90/90 [==============================] - 18s 201ms/step - loss: 0.4629 - accuracy: 0.8557 - val_loss: 0.4043 - val_accuracy: 0.8759
# Epoch 7/100
# 90/90 [==============================] - 16s 178ms/step - loss: 0.3721 - accuracy: 0.8774 - val_loss: 0.3475 - val_accuracy: 0.8842
# Epoch 8/100
# 90/90 [==============================] - 18s 201ms/step - loss: 0.3107 - accuracy: 0.9035 - val_loss: 0.3742 - val_accuracy: 0.8884
# Epoch 9/100
# 90/90 [==============================] - 18s 200ms/step - loss: 0.2869 - accuracy: 0.9077 - val_loss: 0.3480 - val_accuracy: 0.8856
# Epoch 10/100
# 90/90 [==============================] - 18s 202ms/step - loss: 0.2723 - accuracy: 0.9118 - val_loss: 0.3271 - val_accuracy: 0.8996
# Epoch 11/100
# 90/90 [==============================] - 18s 203ms/step - loss: 0.2874 - accuracy: 0.8983 - val_loss: 0.3071 - val_accuracy: 0.8954
# Epoch 12/100
# 90/90 [==============================] - 18s 201ms/step - loss: 0.2286 - accuracy: 0.9213 - val_loss: 0.2872 - val_accuracy: 0.9038
# Epoch 13/100
# 90/90 [==============================] - 18s 202ms/step - loss: 0.1852 - accuracy: 0.9404 - val_loss: 0.2535 - val_accuracy: 0.9177
# Epoch 14/100
# 90/90 [==============================] - 18s 202ms/step - loss: 0.1709 - accuracy: 0.9387 - val_loss: 0.2803 - val_accuracy: 0.9205
# Epoch 15/100
# 90/90 [==============================] - 18s 203ms/step - loss: 0.1724 - accuracy: 0.9394 - val_loss: 0.2275 - val_accuracy: 0.9191
# Epoch 16/100
# 90/90 [==============================] - 16s 177ms/step - loss: 0.1494 - accuracy: 0.9495 - val_loss: 0.2438 - val_accuracy: 0.8996
# Epoch 17/100
# 90/90 [==============================] - 16s 177ms/step - loss: 0.1391 - accuracy: 0.9533 - val_loss: 0.2429 - val_accuracy: 0.9275
# Epoch 18/100
# 90/90 [==============================] - 16s 177ms/step - loss: 0.1335 - accuracy: 0.9540 - val_loss: 0.2520 - val_accuracy: 0.9093
# Epoch 19/100
# 90/90 [==============================] - 18s 201ms/step - loss: 0.1211 - accuracy: 0.9589 - val_loss: 0.2764 - val_accuracy: 0.9052
# Epoch 20/100
# 90/90 [==============================] - 16s 176ms/step - loss: 0.1075 - accuracy: 0.9617 - val_loss: 0.2538 - val_accuracy: 0.9135
# Epoch 21/100
# 90/90 [==============================] - 18s 202ms/step - loss: 0.1343 - accuracy: 0.9596 - val_loss: 0.2511 - val_accuracy: 0.9107
# Epoch 22/100
# 90/90 [==============================] - 18s 202ms/step - loss: 0.1088 - accuracy: 0.9648 - val_loss: 0.2531 - val_accuracy: 0.9093
# Epoch 23/100
# 90/90 [==============================] - 18s 201ms/step - loss: 0.1006 - accuracy: 0.9631 - val_loss: 0.2273 - val_accuracy: 0.9247
# Epoch 24/100
# 90/90 [==============================] - 18s 202ms/step - loss: 0.0810 - accuracy: 0.9725 - val_loss: 0.2251 - val_accuracy: 0.9275
# Epoch 25/100
# 90/90 [==============================] - 18s 202ms/step - loss: 0.0961 - accuracy: 0.9686 - val_loss: 0.2118 - val_accuracy: 0.9219
# Epoch 26/100
# 90/90 [==============================] - 18s 202ms/step - loss: 0.1009 - accuracy: 0.9652 - val_loss: 0.2222 - val_accuracy: 0.9219
# Epoch 27/100
# 90/90 [==============================] - 18s 201ms/step - loss: 0.0861 - accuracy: 0.9746 - val_loss: 0.2104 - val_accuracy: 0.9303
# Epoch 28/100
# 90/90 [==============================] - 16s 178ms/step - loss: 0.0657 - accuracy: 0.9760 - val_loss: 0.2494 - val_accuracy: 0.9163
# Epoch 29/100
# 90/90 [==============================] - 18s 202ms/step - loss: 0.0617 - accuracy: 0.9784 - val_loss: 0.2285 - val_accuracy: 0.9275
# Epoch 30/100
# 90/90 [==============================] - 16s 176ms/step - loss: 0.0643 - accuracy: 0.9760 - val_loss: 0.2187 - val_accuracy: 0.9372
# Epoch 31/100
# 90/90 [==============================] - 16s 178ms/step - loss: 0.0504 - accuracy: 0.9822 - val_loss: 0.2027 - val_accuracy: 0.9344
# Epoch 32/100
# 90/90 [==============================] - 16s 178ms/step - loss: 0.0529 - accuracy: 0.9819 - val_loss: 0.2447 - val_accuracy: 0.9247
# Epoch 33/100
# 90/90 [==============================] - 18s 202ms/step - loss: 0.1317 - accuracy: 0.9533 - val_loss: 0.2805 - val_accuracy: 0.9079
# Epoch 34/100
# 90/90 [==============================] - 18s 200ms/step - loss: 0.1128 - accuracy: 0.9641 - val_loss: 0.1833 - val_accuracy: 0.9303
# Epoch 35/100
# 90/90 [==============================] - 18s 201ms/step - loss: 0.0810 - accuracy: 0.9732 - val_loss: 0.2147 - val_accuracy: 0.9303
# Epoch 36/100
# 90/90 [==============================] - 18s 202ms/step - loss: 0.0896 - accuracy: 0.9659 - val_loss: 0.1813 - val_accuracy: 0.9372
# Epoch 37/100
# 90/90 [==============================] - 16s 177ms/step - loss: 0.0730 - accuracy: 0.9742 - val_loss: 0.1901 - val_accuracy: 0.9442
# Epoch 38/100
# 90/90 [==============================] - 18s 201ms/step - loss: 0.0578 - accuracy: 0.9805 - val_loss: 0.2178 - val_accuracy: 0.9331
# Epoch 39/100
# 90/90 [==============================] - 16s 178ms/step - loss: 0.0361 - accuracy: 0.9899 - val_loss: 0.2269 - val_accuracy: 0.9261
# Epoch 40/100
# 90/90 [==============================] - 16s 178ms/step - loss: 0.0469 - accuracy: 0.9833 - val_loss: 0.2340 - val_accuracy: 0.9289
# Epoch 41/100
# 90/90 [==============================] - 16s 177ms/step - loss: 0.0425 - accuracy: 0.9833 - val_loss: 0.2349 - val_accuracy: 0.9261
# Epoch 42/100
# 90/90 [==============================] - 18s 201ms/step - loss: 0.0534 - accuracy: 0.9819 - val_loss: 0.2044 - val_accuracy: 0.9400
# Epoch 43/100
# 90/90 [==============================] - 16s 178ms/step - loss: 0.0293 - accuracy: 0.9916 - val_loss: 0.2103 - val_accuracy: 0.9372
# Epoch 44/100
# 90/90 [==============================] - 16s 179ms/step - loss: 0.0174 - accuracy: 0.9962 - val_loss: 0.2158 - val_accuracy: 0.9331
# Epoch 45/100
# 90/90 [==============================] - 16s 178ms/step - loss: 0.0137 - accuracy: 0.9976 - val_loss: 0.2418 - val_accuracy: 0.9331
# Epoch 46/100
# 90/90 [==============================] - 18s 201ms/step - loss: 0.0259 - accuracy: 0.9923 - val_loss: 0.2344 - val_accuracy: 0.9275
# Epoch 47/100
# 90/90 [==============================] - 18s 201ms/step - loss: 0.0696 - accuracy: 0.9770 - val_loss: 0.2224 - val_accuracy: 0.9275
# Epoch 48/100
# 90/90 [==============================] - 16s 180ms/step - loss: 0.0517 - accuracy: 0.9819 - val_loss: 0.2204 - val_accuracy: 0.9372
# Epoch 49/100
# 90/90 [==============================] - 16s 179ms/step - loss: 0.0524 - accuracy: 0.9836 - val_loss: 0.2124 - val_accuracy: 0.9261
# Epoch 50/100
# 90/90 [==============================] - 18s 202ms/step - loss: 0.0251 - accuracy: 0.9937 - val_loss: 0.2343 - val_accuracy: 0.9303
# Epoch 51/100
# 90/90 [==============================] - 16s 176ms/step - loss: 0.0131 - accuracy: 0.9976 - val_loss: 0.2783 - val_accuracy: 0.9275
# Epoch 52/100
# 90/90 [==============================] - 16s 177ms/step - loss: 0.0107 - accuracy: 0.9976 - val_loss: 0.2628 - val_accuracy: 0.9358
# Epoch 53/100
# 90/90 [==============================] - 16s 178ms/step - loss: 0.0119 - accuracy: 0.9958 - val_loss: 0.2516 - val_accuracy: 0.9372
# Epoch 54/100
# 90/90 [==============================] - 18s 201ms/step - loss: 0.0136 - accuracy: 0.9962 - val_loss: 0.2700 - val_accuracy: 0.9331
# Epoch 55/100
# 90/90 [==============================] - 16s 176ms/step - loss: 0.0079 - accuracy: 0.9979 - val_loss: 0.2718 - val_accuracy: 0.9386
# Epoch 56/100
# 90/90 [==============================] - 18s 201ms/step - loss: 0.0128 - accuracy: 0.9969 - val_loss: 0.2617 - val_accuracy: 0.9275
# Epoch 57/100
# 90/90 [==============================] - 18s 201ms/step - loss: 0.0695 - accuracy: 0.9735 - val_loss: 0.2660 - val_accuracy: 0.9344
# Epoch 58/100
# 90/90 [==============================] - 18s 201ms/step - loss: 0.0685 - accuracy: 0.9777 - val_loss: 0.2148 - val_accuracy: 0.9317
# Epoch 59/100
# 90/90 [==============================] - 18s 201ms/step - loss: 0.0301 - accuracy: 0.9878 - val_loss: 0.2005 - val_accuracy: 0.9428
# Epoch 60/100
# 90/90 [==============================] - 16s 177ms/step - loss: 0.0178 - accuracy: 0.9927 - val_loss: 0.2807 - val_accuracy: 0.9289
# Epoch 61/100
# 90/90 [==============================] - 18s 201ms/step - loss: 0.0121 - accuracy: 0.9962 - val_loss: 0.2073 - val_accuracy: 0.9372
# Epoch 62/100
# 90/90 [==============================] - 16s 176ms/step - loss: 0.0066 - accuracy: 0.9993 - val_loss: 0.2279 - val_accuracy: 0.9386
# Epoch 63/100
# 90/90 [==============================] - 18s 201ms/step - loss: 0.0029 - accuracy: 0.9997 - val_loss: 0.2344 - val_accuracy: 0.9414
# Epoch 64/100
# 90/90 [==============================] - 16s 177ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.2407 - val_accuracy: 0.9414
# Epoch 65/100
# 90/90 [==============================] - 18s 202ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2499 - val_accuracy: 0.9386
# Epoch 66/100
# 90/90 [==============================] - 18s 201ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2588 - val_accuracy: 0.9358
# Epoch 67/100
# 90/90 [==============================] - 18s 202ms/step - loss: 8.4305e-04 - accuracy: 1.0000 - val_loss: 0.2645 - val_accuracy: 0.9358
# Epoch 68/100
# 90/90 [==============================] - 18s 201ms/step - loss: 6.9022e-04 - accuracy: 1.0000 - val_loss: 0.2752 - val_accuracy: 0.9372
# Epoch 69/100
# 90/90 [==============================] - 16s 178ms/step - loss: 5.6105e-04 - accuracy: 1.0000 - val_loss: 0.2819 - val_accuracy: 0.9372
# Epoch 70/100
# 90/90 [==============================] - 18s 202ms/step - loss: 4.7006e-04 - accuracy: 1.0000 - val_loss: 0.2888 - val_accuracy: 0.9358
# Epoch 71/100
# 90/90 [==============================] - 18s 201ms/step - loss: 4.1552e-04 - accuracy: 1.0000 - val_loss: 0.2915 - val_accuracy: 0.9358
# Epoch 72/100
# 90/90 [==============================] - 18s 202ms/step - loss: 3.5907e-04 - accuracy: 1.0000 - val_loss: 0.3010 - val_accuracy: 0.9386
# Epoch 73/100
# 90/90 [==============================] - 16s 177ms/step - loss: 3.2396e-04 - accuracy: 1.0000 - val_loss: 0.3047 - val_accuracy: 0.9358
# Epoch 74/100
# 90/90 [==============================] - 18s 201ms/step - loss: 2.8626e-04 - accuracy: 1.0000 - val_loss: 0.3087 - val_accuracy: 0.9358
# Epoch 75/100
# 90/90 [==============================] - 18s 201ms/step - loss: 2.6079e-04 - accuracy: 1.0000 - val_loss: 0.3130 - val_accuracy: 0.9358
# Epoch 76/100
# 90/90 [==============================] - 16s 177ms/step - loss: 2.3492e-04 - accuracy: 1.0000 - val_loss: 0.3158 - val_accuracy: 0.9344
# Epoch 77/100
# 90/90 [==============================] - 16s 177ms/step - loss: 2.1713e-04 - accuracy: 1.0000 - val_loss: 0.3221 - val_accuracy: 0.9317
# Epoch 78/100
# 90/90 [==============================] - 18s 201ms/step - loss: 1.9754e-04 - accuracy: 1.0000 - val_loss: 0.3283 - val_accuracy: 0.9344
# Epoch 79/100
# 90/90 [==============================] - 16s 176ms/step - loss: 1.8110e-04 - accuracy: 1.0000 - val_loss: 0.3348 - val_accuracy: 0.9358
# Epoch 80/100
# 90/90 [==============================] - 18s 202ms/step - loss: 1.6881e-04 - accuracy: 1.0000 - val_loss: 0.3367 - val_accuracy: 0.9358
# Epoch 81/100
# 90/90 [==============================] - 16s 177ms/step - loss: 1.5413e-04 - accuracy: 1.0000 - val_loss: 0.3399 - val_accuracy: 0.9331
# Epoch 82/100
# 90/90 [==============================] - 18s 202ms/step - loss: 1.4141e-04 - accuracy: 1.0000 - val_loss: 0.3461 - val_accuracy: 0.9331
# Epoch 83/100
# 90/90 [==============================] - 18s 201ms/step - loss: 1.2927e-04 - accuracy: 1.0000 - val_loss: 0.3509 - val_accuracy: 0.9344
# Epoch 84/100
# 90/90 [==============================] - 18s 204ms/step - loss: 1.2183e-04 - accuracy: 1.0000 - val_loss: 0.3522 - val_accuracy: 0.9331
# Epoch 85/100
# 90/90 [==============================] - 18s 203ms/step - loss: 1.1386e-04 - accuracy: 1.0000 - val_loss: 0.3570 - val_accuracy: 0.9331
# Epoch 86/100
# 90/90 [==============================] - 16s 177ms/step - loss: 1.0735e-04 - accuracy: 1.0000 - val_loss: 0.3595 - val_accuracy: 0.9358
# Epoch 87/100
# 90/90 [==============================] - 16s 177ms/step - loss: 9.7888e-05 - accuracy: 1.0000 - val_loss: 0.3657 - val_accuracy: 0.9344
# Epoch 88/100
# 90/90 [==============================] - 18s 201ms/step - loss: 9.1144e-05 - accuracy: 1.0000 - val_loss: 0.3682 - val_accuracy: 0.9331
# Epoch 89/100
# 90/90 [==============================] - 16s 181ms/step - loss: 8.4780e-05 - accuracy: 1.0000 - val_loss: 0.3713 - val_accuracy: 0.9331
# Epoch 90/100
# 90/90 [==============================] - 17s 185ms/step - loss: 8.0115e-05 - accuracy: 1.0000 - val_loss: 0.3737 - val_accuracy: 0.9344
# Epoch 91/100
# 90/90 [==============================] - 18s 202ms/step - loss: 7.4156e-05 - accuracy: 1.0000 - val_loss: 0.3780 - val_accuracy: 0.9344
# Epoch 92/100
# 90/90 [==============================] - 16s 177ms/step - loss: 6.8641e-05 - accuracy: 1.0000 - val_loss: 0.3804 - val_accuracy: 0.9331
# Epoch 93/100
# 90/90 [==============================] - 18s 201ms/step - loss: 6.5388e-05 - accuracy: 1.0000 - val_loss: 0.3834 - val_accuracy: 0.9344
# Epoch 94/100
# 90/90 [==============================] - 18s 201ms/step - loss: 6.0780e-05 - accuracy: 1.0000 - val_loss: 0.3860 - val_accuracy: 0.9331
# Epoch 95/100
# 90/90 [==============================] - 18s 201ms/step - loss: 5.6550e-05 - accuracy: 1.0000 - val_loss: 0.3910 - val_accuracy: 0.9331
# Epoch 96/100
# 90/90 [==============================] - 16s 177ms/step - loss: 5.3565e-05 - accuracy: 1.0000 - val_loss: 0.3922 - val_accuracy: 0.9331
# Epoch 97/100
# 90/90 [==============================] - 18s 201ms/step - loss: 4.9744e-05 - accuracy: 1.0000 - val_loss: 0.3964 - val_accuracy: 0.9331
# Epoch 98/100
# 90/90 [==============================] - 18s 202ms/step - loss: 4.7022e-05 - accuracy: 1.0000 - val_loss: 0.3976 - val_accuracy: 0.9331
# Epoch 99/100
# 90/90 [==============================] - 18s 201ms/step - loss: 4.3705e-05 - accuracy: 1.0000 - val_loss: 0.4041 - val_accuracy: 0.9331
# Epoch 100/100
# 90/90 [==============================] - 18s 202ms/step - loss: 4.1247e-05 - accuracy: 1.0000 - val_loss: 0.4050 - val_accuracy: 0.9331
# 23/23 [==============================] - 3s 129ms/step - loss: 0.4050 - accuracy: 0.9331
# Test Accuracy: 0.9330543875694275
# Train Accuracy: 1.0
